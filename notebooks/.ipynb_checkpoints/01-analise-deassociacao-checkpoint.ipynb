# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (2.3.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (0.23.4)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from mlxtend) (1.16.1)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from mlxtend) (2.3.2)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from mlxtend) (1.7.2)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from mlxtend) (3.10.6)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\miche\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
# Para esta prática, vamos criar um dataset de transaçõesdiretamente no código.
# Cada lista interna representa uma cesta de compras de um cliente.
transactions = [
 ['leite', 'pao', 'manteiga'],
 ['cerveja', 'fraldas', 'batata_chips'],
 ['leite', 'fraldas', 'pao', 'cerveja'],
 ['pao', 'manteiga', 'geleia'],
 ['cafe', 'pao', 'acucar'],
 ['leite', 'pao', 'cerveja'],
 ['cerveja', 'fraldas'],
 ['leite', 'cafe', 'pao', 'manteiga']
]

# %%
# O algoritmo Apriori precisa de dados em um formato específico (one-hot encoded).
# O TransactionEncoder faz essa conversão para nós.
te = TransactionEncoder()
te_ary = te.fit(transactions).transform(transactions)
df_encoded = pd.DataFrame(te_ary, columns=te.columns_)
print("Dados transformados (formato one-hot):")
display(df_encoded)
# Out:
# Dados transformados (formato one-hot):
#    acucar  batata_chips   cafe  cerveja  fraldas  geleia  leite  manteiga  \
# 0   False         False  False    False    False   False   True      True
# 1   False          True  False     True     True   False  False     False
# 2   False         False  False     True     True   False   True     False
# 3   False         False  False    False    False    True  False      True
# 4    True         False   True    False    False   False  False     False
# 5   False         False  False     True    False   False   True     False
# 6   False         False  False     True     True   False  False     False
# 7   False         False   True    False    False   False   True      True
#
#      pao
# 0   True
# 1  False
# 2   True
# 3   True
# 4   True
# 5   True
# 6  False
# 7   True

# %%
# O Apriori encontra conjuntos de itens que aparecem juntos com uma frequência mínima.
# `min_support` é a frequência mínima para um conjunto de itens ser considerado "frequente".
# Suporte = (Nº de transações com o item) / (Total de transações)
frequent_itemsets = apriori(df_encoded, min_support=0.25,
use_colnames=True)
print("\nConjuntos de Itens Frequentes (Suporte >= 25%):")
display(frequent_itemsets)
# Out:
# Conjuntos de Itens Frequentes (Suporte >= 25%):
#     support                itemsets
# 0     0.250                  (cafe)
# 1     0.500               (cerveja)
# 2     0.375               (fraldas)
# 3     0.500                 (leite)
# 4     0.375              (manteiga)
# 5     0.750                   (pao)
# 6     0.250             (cafe, pao)
# 7     0.375      (fraldas, cerveja)
# 8     0.250        (leite, cerveja)
# 9     0.250          (pao, cerveja)
# 10    0.250       (leite, manteiga)
# 11    0.500            (leite, pao)
# 12    0.375         (pao, manteiga)
# 13    0.250   (leite, pao, cerveja)
# 14    0.250  (leite, pao, manteiga)

# %%
# A partir dos itens frequentes, geramos as regras de associação.
# Métrica principal: 'confidence' (Confiança) ou 'lift' (Elevação).
# Confiança({A} -> {B}) = Quão frequentemente B é comprado quando A é comprado.
# Lift({A} -> {B}) = Quão mais provável é comprar B quando A é comprado, em comparação com a probabilidade normal de comprar B.
# Lift > 1 indica uma associação positiva.
rules = association_rules(frequent_itemsets, metric="lift",
min_threshold=1.2)
# Filtrar e ordenar para ver as regras mais interessantes
rules_filtered = rules[rules['confidence'] >=
0.6].sort_values(by='lift', ascending=False)
print("\nRegras de Associação Geradas (Lift > 1.2 e Confiança >=60%):")
display(rules_filtered)
# Out:
# Regras de Associação Geradas (Lift > 1.2 e Confiança >=60%):
#           antecedents   consequents  antecedent support  consequent support  \
# 2           (fraldas)     (cerveja)               0.375               0.500
# 3           (cerveja)     (fraldas)               0.500               0.375
# 11     (pao, cerveja)       (leite)               0.250               0.500
# 0              (cafe)         (pao)               0.250               0.750
# 5          (manteiga)       (leite)               0.375               0.500
# 6             (leite)         (pao)               0.500               0.750
# 9          (manteiga)         (pao)               0.375               0.750
# 7               (pao)       (leite)               0.750               0.500
# 10   (leite, cerveja)         (pao)               0.250               0.750
# 15  (leite, manteiga)         (pao)               0.250               0.750
# 16    (pao, manteiga)       (leite)               0.375               0.500
# 19         (manteiga)  (leite, pao)               0.375               0.500
#
#     support  confidence      lift  representativity  leverage  conviction  \
# 2     0.375    1.000000  2.000000               1.0   0.18750         inf
# 3     0.375    0.750000  2.000000               1.0   0.18750         2.5
# 11    0.250    1.000000  2.000000               1.0   0.12500         inf
# 0     0.250    1.000000  1.333333               1.0   0.06250         inf
# 5     0.250    0.666667  1.333333               1.0   0.06250         1.5
# 6     0.500    1.000000  1.333333               1.0   0.12500         inf
# 9     0.375    1.000000  1.333333               1.0   0.09375         inf
# 7     0.500    0.666667  1.333333               1.0   0.12500         1.5
# 10    0.250    1.000000  1.333333               1.0   0.06250         inf
# 15    0.250    1.000000  1.333333               1.0   0.06250         inf
# 16    0.250    0.666667  1.333333               1.0   0.06250         1.5
# 19    0.250    0.666667  1.333333               1.0   0.06250         1.5
#
#     zhangs_metric   jaccard  certainty  kulczynski
# 2        0.800000  0.750000   1.000000    0.875000
# 3        1.000000  0.750000   0.600000    0.875000
# 11       0.666667  0.500000   1.000000    0.750000
# 0        0.333333  0.333333   1.000000    0.666667
# 5        0.400000  0.400000   0.333333    0.583333
# 6        0.500000  0.666667   1.000000    0.833333
# 9        0.400000  0.500000   1.000000    0.750000
# 7        1.000000  0.666667   0.333333    0.833333
# 10       0.333333  0.333333   1.000000    0.666667
# 15       0.333333  0.333333   1.000000    0.666667
# 16       0.400000  0.400000   0.333333    0.583333
# 19       0.400000  0.400000   0.333333    0.583333
